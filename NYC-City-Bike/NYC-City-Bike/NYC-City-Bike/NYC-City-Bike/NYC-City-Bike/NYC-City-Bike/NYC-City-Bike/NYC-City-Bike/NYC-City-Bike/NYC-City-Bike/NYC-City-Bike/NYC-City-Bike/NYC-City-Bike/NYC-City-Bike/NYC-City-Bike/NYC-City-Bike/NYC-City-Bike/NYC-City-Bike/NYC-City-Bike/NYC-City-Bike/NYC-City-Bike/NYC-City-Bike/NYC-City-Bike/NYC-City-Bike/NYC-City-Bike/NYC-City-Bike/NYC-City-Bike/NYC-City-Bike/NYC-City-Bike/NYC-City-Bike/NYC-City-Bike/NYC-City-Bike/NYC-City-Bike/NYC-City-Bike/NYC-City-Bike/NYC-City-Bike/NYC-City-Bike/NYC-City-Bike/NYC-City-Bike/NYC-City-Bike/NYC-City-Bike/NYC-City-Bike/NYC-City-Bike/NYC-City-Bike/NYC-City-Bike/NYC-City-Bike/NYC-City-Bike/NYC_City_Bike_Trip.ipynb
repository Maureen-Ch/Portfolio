# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('https://raw.githubusercontent.com/mamaggie/TutorialProjects/refs/heads/main/data/citi_bike_trip_data.csv')

# %%
df.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           326  2013-10-01 00:01:08  2013-10-01 00:06:34               239
# 1           729  2013-10-01 00:01:21  2013-10-01 00:13:30               322
# 2           520  2013-10-01 00:01:24  2013-10-01 00:10:04               174
# 3           281  2013-10-01 00:01:25  2013-10-01 00:06:06               430
# 4           196  2013-10-01 00:01:27  2013-10-01 00:04:43               403
#
#          start station name  start station latitude  start station longitude  \
# 0  Willoughby St & Fleet St               40.691966               -73.981302
# 1   Clinton St & Tillary St               40.696192               -73.991218
# 2           E 25 St & 1 Ave               40.738177               -73.977387
# 3          York St & Jay St               40.701485               -73.986569
# 4            E 2 St & 2 Ave               40.725029               -73.990697
#
#    end station id             end station name  end station latitude  \
# 0             366     Clinton Ave & Myrtle Ave             40.693261
# 1             398     Atlantic Ave & Furman St             40.691652
# 2             403               E 2 St & 2 Ave             40.725029
# 3             323  Lawrence St & Willoughby St             40.692362
# 4             401      Allen St & Rivington St             40.720196
#
#    end station longitude  bikeid    usertype birth year  gender
# 0             -73.968896   16052  Subscriber       1982       1
# 1             -73.999979   19412    Customer         \N       0
# 2             -73.990697   19645  Subscriber       1984       1
# 3             -73.986317   16992  Subscriber       1985       1
# 4             -73.989978   15690  Subscriber       1986       1

# %%
df.shape
# Out:
# (40575, 15)

# %%
df.columns
# Out:
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
df.describe()
# Out:
#        tripduration  start station id  start station latitude  \
# count  40575.000000      40575.000000            40575.000000
# mean     822.374640        449.396155               40.735229
# std      984.000376        362.462577                0.019599
# min       60.000000         72.000000               40.680342
# 25%      408.000000        306.000000               40.721816
# 50%      638.000000        405.000000               40.737050
# 75%     1028.000000        487.000000               40.750450
# max    56629.000000       3002.000000               40.770513
#
#        start station longitude  end station id  end station latitude  \
# count             40575.000000    40575.000000          40575.000000
# mean                -73.991093      450.073370             40.734885
# std                   0.012346      369.780126              0.019600
# min                 -74.017134       72.000000             40.680342
# 25%                 -74.000264      305.000000             40.721816
# 50%                 -73.990765      404.000000             40.736529
# 75%                 -73.982050      487.000000             40.750224
# max                 -73.950048     3002.000000             40.770513
#
#        end station longitude        bikeid        gender
# count           40575.000000  40575.000000  40575.000000
# mean              -73.991212  17634.191547      1.137671
# std                 0.012483   1703.451047      0.527477
# min               -74.017134  14531.000000      0.000000
# 25%               -74.001497  16146.000000      1.000000
# 50%               -73.990931  17651.000000      1.000000
# 75%               -73.982050  19093.000000      1.000000
# max               -73.950048  20664.000000      2.000000

# %%
sns.histplot(df['tripduration'])
# Out:
# <Axes: xlabel='tripduration', ylabel='Count'>

# %%
sns.pairplot(df)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
sns.pairplot(df[['tripduration','gender']])

# %% [markdown]
# How many % users are subscribers ?

# %%
num_subscriber = df['usertype'].loc[df['usertype']== 'Subscriber'].count()
total = len(df)
print(round(num_subscriber/total*100, 2), '% of total on October 1st,2013 is annual subscribers')
# Out:
# 92.03 % of total on October 1st,2013 is annual subscribers

# %% [markdown]
# ### How does trip length vary based on trip start time ?

# %%
df['hour'] = df.starttime.apply(lambda x:x[11:13]).astype('str')

# %%
#visualize correlation
sns.scatterplot(x = 'hour', y = 'tripduration', data = df)
# Out:
# <Axes: xlabel='hour', ylabel='tripduration'>

# %%
#On remarque que les trajet sont plus long entre 7h-12h et 17h-20h.

# %%
sns.scatterplot(x = 'hour', y = 'tripduration', data = df, hue = 'usertype')
# Out:
# <Axes: xlabel='hour', ylabel='tripduration'>

# %%
# subscribers take longer trip than non-subscribers.

# %% [markdown]
# ### Which bike stations are more popular to start trips from ?

# %%
df2 = df.groupby(['start station id']).size().reset_index(name = 'counts')

# %%
df2
# Out:
#      start station id  counts
# 0                  72     112
# 1                  79      91
# 2                  82      39
# 3                  83      52
# 4                 116     213
# ..                ...     ...
# 323              2017     127
# 324              2021     228
# 325              2022     105
# 326              2023      74
# 327              3002     186
#
# [328 rows x 2 columns]

# %%
temp = df.drop_duplicates('start station id')
#left join
df2 = pd.merge(df2, temp[['start station id', 'start station name', 'start station latitude','start station longitude']],
how = 'left', on =['start station id'])

# %%
df2
# Out:
#      start station id  counts             start station name  \
# 0                  72     112               W 52 St & 11 Ave
# 1                  79      91       Franklin St & W Broadway
# 2                  82      39         St James Pl & Pearl St
# 3                  83      52  Atlantic Ave & Fort Greene Pl
# 4                 116     213                W 17 St & 8 Ave
# ..                ...     ...                            ...
# 323              2017     127                E 43 St & 2 Ave
# 324              2021     228                W 45 St & 8 Ave
# 325              2022     105            E 59 St & Sutton Pl
# 326              2023      74        E 55 St & Lexington Ave
# 327              3002     186     South End Ave & Liberty St
#
#      start station latitude  start station longitude
# 0                 40.767272               -73.993929
# 1                 40.719116               -74.006667
# 2                 40.711174               -74.000165
# 3                 40.683826               -73.976323
# 4                 40.741776               -74.001497
# ..                      ...                      ...
# 323               40.750224               -73.971214
# 324               40.759291               -73.988597
# 325               40.758491               -73.959206
# 326               40.759681               -73.970314
# 327               40.711512               -74.015756
#
# [328 rows x 5 columns]

# %% [markdown]
# ## Visualization

# %%
import folium

# %%
#initialize map
m = folium.Map(location = [40.767272 , -73.993929], tiles = 'OpenStreetMap', zoom_start= 12)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5a3560a78f4feb649a6c90899fdb5bd9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5a3560a78f4feb649a6c90899fdb5bd9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5a3560a78f4feb649a6c90899fdb5bd9 = L.map(
#                 &quot;map_5a3560a78f4feb649a6c90899fdb5bd9&quot;,
#                 {
#                     center: [40.767272, -73.993929],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_08135f816c70a488c793f5c4ea4754da = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_08135f816c70a488c793f5c4ea4754da.addTo(map_5a3560a78f4feb649a6c90899fdb5bd9);
#
#
#             tile_layer_08135f816c70a488c793f5c4ea4754da.addTo(map_5a3560a78f4feb649a6c90899fdb5bd9);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for i in range(0, len(df2)):
  folium.Circle(
      location = [df.loc[i]['start station latitude'], df.loc[i]['start station longitude']],
      popup = df2.loc[i]['start station name'],
      radius = float(df2.loc[i]['counts'])/2,
      color = 'red',
      fill = True, fill_color = 'red'
  ).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5a3560a78f4feb649a6c90899fdb5bd9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5a3560a78f4feb649a6c90899fdb5bd9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5a3560a78f4feb649a6c90899fdb5bd9 = L.map(
#                 &quot;map_5a3560a78f4feb649a6c90899fdb5bd9&quot;,
#                 {
#                     center: [40.767272, -73.993929],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_08135f816c70a488c793f5c4ea4754da = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_08135f816c70a488c793f5c4ea4754da.addTo(map_5a3560a78f4feb649a6c90899fdb5bd9);
#
#
#             tile_layer_08135f816c70a488c793f5c4ea4754da.addTo(map_5a3560a78f4feb649a6c90899fdb5bd9);
#
#
#             tile_layer_08135f816c70a488c793f5c4ea4754da.addTo(map_5a3560a78f4feb649a6c90899fdb5bd9);
#
#
#             var circle_273563eaf5ec96c83a3ccbd3e847dbf8 = L.circle(
#                 [40.69196566, -73.9813018],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 56.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5a3560a78f4feb649a6c90899fdb5bd9);
#
#
#         var popup_07dca9d9cb041bed67ced0e882de5b84 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2a5f1c1a1da438280183b5017baf18bd = $(`&lt;div id=&quot;html_2a5f1c1a1da438280183b5017baf18bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;W 52 St &amp; 11 Ave&lt;/div&gt;`)[0];
#                 popup_07dca9d9cb041bed67ced0e882de5b84.setContent(html_2a5f1c1a1da438280183b5017baf18bd);
#
#
#
#         circle_273563eaf5ec96c83a3ccbd3e847dbf8.bindPopup(popup_07dca9d9cb041bed67ced0e882de5b84)
#         ;
#
#
#
#
#             var circle_973f620ffacc505d411bdf741949aac0 = L.circle(
#                 [40.696192, -73.991218],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 45.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5a3560a78f4feb649a6c90899fdb5bd9);
#
#
#         var popup_d16aa1532a81a4ba2d9b7562733f0875 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5a6f2ae21482c23f4974e0d9aee0477d = $(`&lt;div id=&quot;html_5a6f2ae21482c23f4974e0d9aee0477d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Franklin St &amp; W Broadway&lt;/div&gt;`)[0];
#                 popup_d16aa1532a81a4ba2d9b7562733f0875.setContent(html_5a6f2ae21482c23f4974e0d9aee0477d);
#
#
#
#         circle_973f620ffacc505d411bdf741949aac0.bindPopup(popup_d16aa1532a81a4ba2d9b7562733f0875)
#         ;
#
#
#
#
#             var circle_5ff7d959339ebbe03ec797d9e6bded16 = L.circle(
#                 [40.7381765, -73.97738662],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 19.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5a3560a78f4feb649a6c90899fdb5bd9);
#
#
#         var popup_eff1a08551fe444d7e5a12a33f6387a2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9a575c7556a629445b2315cc3519da2c = $(`&lt;div id=&quot;html_9a575c7556a629445b2315cc3519da2c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;St James Pl &amp; Pearl St&lt;/div&gt;`)[0];
#                 popup_eff1a08551fe444d7e5a12a33f6387a2.setContent(html_9a575c7556a629445b2315cc3519da2c);
